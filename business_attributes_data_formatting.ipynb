# %%
import pandas as pd
import numpy as np
import ast
import re
from collections import defaultdict

# %%
business_train = pd.read_json('business_test.json',orient = 'records',lines = True)

# %%
def nestedValue(x:str):
    """judge if a string contains nested json information"""
    return re.match(u'{.*}',x)

### first extract the column names from nested json
colnames=[]
for attribute in business_train.attributes:
    if attribute==None:
        continue
    for key,value in attribute.items():
        if not nestedValue(value):
            colnames.append(key)
        else:
            for nestKey,nestValue in ast.literal_eval(value).items():
                colnames.append(nestKey)
colnames=set(colnames)

### second extract the value from nested json file
res=defaultdict(list)
count=0
for attribute in business_train.attributes:
    if attribute==None:
        continue
    for i in colnames:
        res[i].append(None)
    for key,value in attribute.items():
        if not nestedValue(value):
            res[key][count]=value
        else:
            for nestKey,nestValue in ast.literal_eval(value).items():
                res[nestKey][count]=nestValue
            
    count+=1

# %%
pd.DataFrame(res)
# Out:
#       asian    BYOBCorkage    dj coloring DogsAllowed Corkage OutdoorSeating  \
# 0      None           None  None     None        None    None          False
# 1      None           None  None     None        None    None           None
# 2      None           None  None     None        None    None           None
# 3      None           None  None     None        None    None           None
# 4      None           None  None     None        None    None           None
# 5      None           None  None     None        None    None          False
# 6      None           None  None     None        None    None           None
# 7      None           None  None     None        None    None           None
# 8      None           None  None     None        None    None           None
# 9      None           None  None     None        None    None           None
# 10     None           None  None     None        None    None           True
# 11     None           None  None     None        None    None           None
# 12     None           None  None     None        None    None           None
# 13     None           None  None     None        None    None          False
# 14     None           None  None     None        None    None           None
# 15     None           None  None     None       False    None           True
# 16     None           None  None     None        None    None           True
# 17     None           None  None     None        None    None           None
# 18     None           None  None     None        None    None          False
# 19     None           None  None     None        None    None           None
# 20     None           None  None     None        None    None           None
# 21     None           None  None     None        None    None           None
# 22     None           None  None     None       False    None           None
# 23     None           None  None     None        None    None          False
# 24     None           None  None     None       False    None          False
# 25     None  'yes_corkage'  None     None        None    True          False
# 26     None           None  None     None        None    None           True
# 27     None           None  None     None        None    None          False
# 28     None           None  None     None        None    None           None
# 29     None           None  None     None        None    None           True
# ...     ...            ...   ...      ...         ...     ...            ...
# 32341  None           None  None     None        None    None           None
# 32342  None           None  None     None        None    None           None
# 32343  None           None  None     None        None    None           True
# 32344  None           None  None     None        None    None           None
# 32345  None           None  None     None        None    None           None
# 32346  None           None  None     None        None    None           None
# 32347  None           None  None     None        None    None           None
# 32348  None           None  None     None        None    None           None
# 32349  None           None  None     None        None    None           None
# 32350  None           None  None     None        True    None           True
# 32351  None           None  None     None        None    None           None
# 32352  None           None  None     None        None    None          False
# 32353  None           None  None     None        None    None           None
# 32354  None           None  None     None        None    None          False
# 32355  None           None  None     None        None    None           True
# 32356  None           None  None     None        None    None           True
# 32357  None           None  None     None        None    None          False
# 32358  None           None  None     None        None    None           None
# 32359  None           None  None     None        None    None           None
# 32360  None           None  None     None        None    None           True
# 32361  None           None  None     None        None    None           None
# 32362  None           None  None     None        None    None           None
# 32363  None           None  None     None        True    None          False
# 32364  None           None  None     None        None    None           None
# 32365  None           None  None     None        None    None           None
# 32366  None           None  None     None        None    None           None
# 32367  None           None  None     None        None    None          False
# 32368  None           None  None     None        None    None           None
# 32369  None           None  None     None        None    None           None
# 32370  None           None  None     None        None    None           None
#
#       no_music street soy-free   ...    perms RestaurantsTableService  \
# 0         None  False     None   ...     None                    True
# 1         None  False     None   ...     None                    None
# 2         None  False     None   ...     None                    None
# 3         None  False     None   ...     None                    None
# 4         None   True     None   ...     None                    None
# 5         None  False     None   ...     None                    None
# 6         None  False     None   ...     None                    None
# 7         None   None     None   ...     None                    None
# 8         None   None     None   ...     None                    None
# 9         None   None     None   ...     None                    None
# 10        None  False     None   ...     None                    None
# 11        None  False     None   ...     None                    None
# 12        None  False     None   ...     None                    None
# 13        None  False     None   ...     None                    None
# 14        None   True     None   ...     None                    None
# 15        None   True     None   ...     None                    True
# 16        None   None     None   ...     None                    None
# 17        None  False     None   ...     None                    None
# 18        None   True     None   ...     None                    None
# 19        None  False     None   ...     None                    None
# 20        None   None     None   ...     None                    None
# 21        None  False     None   ...     None                    None
# 22        None  False     None   ...     None                    None
# 23        None  False     None   ...     None                    True
# 24        None  False     None   ...     None                   False
# 25        None  False     None   ...     None                    None
# 26        None  False     None   ...     None                    True
# 27        None  False     None   ...     None                    None
# 28        None   None     None   ...     None                    None
# 29        None  False     None   ...     None                    None
# ...        ...    ...      ...   ...      ...                     ...
# 32341     None   None     None   ...     None                    None
# 32342     None   None     None   ...     None                    None
# 32343     None   True     None   ...     None                    None
# 32344     None   None     None   ...     None                    None
# 32345     None  False     None   ...     None                    None
# 32346     None   None     None   ...     None                    None
# 32347     None   None     None   ...     None                    None
# 32348     None  False     None   ...     None                    None
# 32349     None  False     None   ...     None                    None
# 32350     None   True     None   ...     None                    True
# 32351     None  False     None   ...     None                    None
# 32352     None   None     None   ...     None                    None
# 32353     None   True     None   ...     None                    None
# 32354     None  False     None   ...     None                    None
# 32355     None   True     None   ...     None                    None
# 32356     None  False     None   ...     None                    None
# 32357     None  False     None   ...     None                    None
# 32358     None   None     None   ...     None                    None
# 32359     None   None     None   ...     None                    None
# 32360     None  False     None   ...     None                    None
# 32361     None   None     None   ...     None                    None
# 32362     None   None     None   ...     None                    None
# 32363     None   True     None   ...     None                   False
# 32364     None  False     None   ...     None                    None
# 32365     None  False     None   ...     None                    None
# 32366     None   None     None   ...     None                    None
# 32367     None   True     None   ...     None                    None
# 32368     None   None     None   ...     None                    None
# 32369     None  False     None   ...     None                    None
# 32370     None  False     None   ...     None                    None
#
#       wednesday HairSpecializesIn Open24Hours tuesday intimate  \
# 0          None              None        None    None    False
# 1          None              None        None    None     None
# 2          None              None        None    None     None
# 3          None              None        None    None     None
# 4          None              None        None    None     None
# 5          None              None        None    None     None
# 6          None              None        None    None     None
# 7          None              None        None    None     None
# 8          None              None        None    None     None
# 9          None              None        None    None     None
# 10         None              None        None    None    False
# 11         None              None        None    None     None
# 12         None              None        None    None     None
# 13         None              None        None    None    False
# 14         None              None        None    None     None
# 15         None              None        None    None    False
# 16         None              None        None    None     None
# 17         None              None        None    None     None
# 18         None              None        None    None    False
# 19         None              None        None    None     None
# 20         None              None        None    None     None
# 21         None              None        None    None     None
# 22         None              None        None    None     None
# 23         None              None        None    None    False
# 24         None              None        None    None    False
# 25         None              None        None    None     None
# 26         None              None        None    None    False
# 27         None              None        None    None    False
# 28         None              None        None    None     None
# 29         None              None        None    None    False
# ...         ...               ...         ...     ...      ...
# 32341      None              None        None    None     None
# 32342      None              None        None    None     None
# 32343      None              None        None    None    False
# 32344      None              None        None    None     None
# 32345      None              None        None    None     None
# 32346      None              None        None    None     None
# 32347      None              None        None    None     None
# 32348      None              None        None    None     None
# 32349      None              None        None    None     None
# 32350      None              None        None    None    False
# 32351      None              None        None    None     None
# 32352      None              None        None    None    False
# 32353      None              None        None    None     None
# 32354      None              None        None    None     None
# 32355      None              None        None    None    False
# 32356      None              None        None    None    False
# 32357      None              None        None    None    False
# 32358      None              None        None    None     None
# 32359      None              None        None    None     None
# 32360      None              None        None    None    False
# 32361      None              None        None    None     None
# 32362      None              None        None    None     None
# 32363      None              None        None    None    False
# 32364      None              None        None    None     None
# 32365      None              None        None    None     None
# 32366      None              None        None    None     None
# 32367      None              None        None    None    False
# 32368      None              None        None    None     None
# 32369      None              None        None    None     None
# 32370      None              None        None    None     None
#
#       BusinessParking vegan Ambience
# 0                None  None     None
# 1                None  None     None
# 2                None  None     None
# 3                None  None     None
# 4                None  None     None
# 5                None  None     None
# 6                None  None     None
# 7                None  None     None
# 8                None  None     None
# 9                None  None     None
# 10               None  None     None
# 11               None  None     None
# 12               None  None     None
# 13               None  None     None
# 14               None  None     None
# 15               None  None     None
# 16               None  None     None
# 17               None  None     None
# 18               None  None     None
# 19               None  None     None
# 20               None  None     None
# 21               None  None     None
# 22               None  None     None
# 23               None  None     None
# 24               None  None     None
# 25               None  None     None
# 26               None  None     None
# 27               None  None     None
# 28               None  None     None
# 29               None  None     None
# ...               ...   ...      ...
# 32341            None  None     None
# 32342            None  None     None
# 32343            None  None     None
# 32344            None  None     None
# 32345            None  None     None
# 32346            None  None     None
# 32347            None  None     None
# 32348            None  None     None
# 32349            None  None     None
# 32350            None  None     None
# 32351            None  None     None
# 32352            None  None     None
# 32353            None  None     None
# 32354            None  None     None
# 32355            None  None     None
# 32356            None  None     None
# 32357            None  None     None
# 32358            None  None     None
# 32359            None  None     None
# 32360            None  None     None
# 32361            None  None     None
# 32362            None  None     None
# 32363            None  None     None
# 32364            None  None     None
# 32365            None  None     None
# 32366            None  None     None
# 32367            None  None     None
# 32368            None  None     None
# 32369            None  None     None
# 32370            None  None     None
#
# [32371 rows x 87 columns]

# %%
business_train.attributes[0]["BusinessParking"]
# Out:
# "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}"

# %%
business_train.attributes[1]
# Out:
# {'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'RestaurantsPriceRange2': '2'}

# %%
business_train.attributes[2]
# Out:
# {'BusinessAcceptsCreditCards': 'True',
#  'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#  'GoodForKids': 'True',
#  'RestaurantsPriceRange2': '2',
#  'ByAppointmentOnly': 'True'}

# %%
set([1,1,1])
# Out:
# {1}
